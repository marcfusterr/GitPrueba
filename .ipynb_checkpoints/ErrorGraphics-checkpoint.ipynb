# %% [markdown]
# # LOAD LIBRARIES

# %%
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
from datetime import datetime
import seaborn as sns
from fbprophet import Prophet
import sqlalchemy




plt.style.use('seaborn')

# %% [markdown]
# # CONNECT TO SQL SERVER

# %%
engine = sqlalchemy.create_engine \
("mssql+pyodbc://marc.fuster:access.to.sql19@database.kernel-analytics.local/byl_supply_chain?driver=ODBC+Driver+13+for+SQL+Server")

# %% [markdown]
# # by DAY

# %%
sql = """select * from dbo.marc_by_day_2018 order by Dia"""
df_day = pd.read_sql(sql, engine)
df_day.head()
# Out:
#           Dia  cantidad
# 0  2018-01-01      4959
# 1  2018-01-02     55614
# 2  2018-01-03     60449
# 3  2018-01-04     62760
# 4  2018-01-05     55927

# %%
df_day['Numero Dia']=df_day.index.values

# %%
df_day.head()
# Out:
#           Dia  cantidad  Numero Dia
# 0  2018-01-01      4959           0
# 1  2018-01-02     55614           1
# 2  2018-01-03     60449           2
# 3  2018-01-04     62760           3
# 4  2018-01-05     55927           4

# %% [markdown]
# ## Convert it to prophet type

# %%
df_day = df_day.rename(columns={'Dia': 'ds', 'cantidad': 'y'})

# %%
df_day.head()
# Out:
#            ds      y  Numero Dia
# 0  2018-01-01   4959           0
# 1  2018-01-02  55614           1
# 2  2018-01-03  60449           2
# 3  2018-01-04  62760           3
# 4  2018-01-05  55927           4

# %% [markdown]
# # Fit and predict With logistic and floor and cap

# %%
# to introduce floor value

df_day['floor'] = 0.
df_day['cap'] = 1e5

m_day = Prophet(yearly_seasonality=True, weekly_seasonality=True ,  changepoint_range=0.95 , growth='logistic' , seasonality_mode=\
               "multiplicative")
m_day.fit(df_day)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_day = m_day.make_future_dataframe(periods=365)

# to introduce floor value
future_day['floor'] = 0.
future_day['cap'] = 1e5


future_day.tail()
# Out:
#             ds  floor       cap
# 725 2019-12-27    0.0  100000.0
# 726 2019-12-28    0.0  100000.0
# 727 2019-12-29    0.0  100000.0
# 728 2019-12-30    0.0  100000.0
# 729 2019-12-31    0.0  100000.0

# %%
forecast_day = m_day.predict(future_day)
#forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
forecast_day['Numerio Dia']=forecast_day.index.tolist()

forecast_day.tail()
# Out:
#             ds         trend       cap  floor    yhat_lower    yhat_upper  \
# 725 2019-12-27  11667.610575  100000.0    0.0  17026.402197  36717.915887
# 726 2019-12-28  11658.612266  100000.0    0.0  17975.008408  37811.211816
# 727 2019-12-29  11649.619981  100000.0    0.0  10824.485857  30567.799529
# 728 2019-12-30  11640.633718  100000.0    0.0  13995.237478  33167.458921
# 729 2019-12-31  11631.653474  100000.0    0.0  14543.348495  34443.564800
#
#      trend_lower   trend_upper  multiplicative_terms  \
# 725  9826.835882  13933.188711              1.272819
# 726  9804.785096  13925.047906              1.342646
# 727  9783.932779  13920.982544              0.760274
# 728  9765.275149  13919.172454              1.032039
# 729  9746.649396  13917.362631              1.048733
#
#      multiplicative_terms_lower     ...       weekly_lower  weekly_upper  \
# 725                    1.272819     ...           0.199622      0.199622
# 726                    1.342646     ...           0.248910      0.248910
# 727                    0.760274     ...          -0.350833     -0.350833
# 728                    1.032039     ...          -0.093005     -0.093005
# 729                    1.048733     ...          -0.086588     -0.086588
#
#        yearly  yearly_lower  yearly_upper  additive_terms  \
# 725  1.073197      1.073197      1.073197             0.0
# 726  1.093736      1.093736      1.093736             0.0
# 727  1.111106      1.111106      1.111106             0.0
# 728  1.125045      1.125045      1.125045             0.0
# 729  1.135320      1.135320      1.135320             0.0
#
#      additive_terms_lower  additive_terms_upper          yhat  Numerio Dia
# 725                   0.0                   0.0  26518.364981          725
# 726                   0.0                   0.0  27312.003967          726
# 727                   0.0                   0.0  20506.517730          727
# 728                   0.0                   0.0  23654.223052          728
# 729                   0.0                   0.0  23830.146693          729
#
# [5 rows x 22 columns]

# %%
df_day.head()
# Out:
#            ds      y  Numero Dia  floor       cap
# 0  2018-01-01   4959           0    0.0  100000.0
# 1  2018-01-02  55614           1    0.0  100000.0
# 2  2018-01-03  60449           2    0.0  100000.0
# 3  2018-01-04  62760           3    0.0  100000.0
# 4  2018-01-05  55927           4    0.0  100000.0

# %% [markdown]
# ## Plots

# %%
fig2 = m_day.plot_components(forecast_day)
plt.show()

# %%
plt.figure(figsize=(15,10))
fig1 = m_day.plot(forecast_day)
plt.title(r'Daily Model')
plt.show()

# %%
plt.scatter(x=forecast_day['Numerio Dia'].tolist(),y=forecast_day['yhat'].tolist(),color='r', label=r'Model')
plt.scatter(x=df_day.index.values.tolist(),y=df_day['y'].tolist(), label=r'Original data')
plt.legend()
plt.show()

# %% [markdown]
# # WEEK basis

# %%
sql = """select * from dbo.marc_by_week_2018 order by WeekStart"""
df_week = pd.read_sql(sql, engine)
df_week.head()
# Out:
#    WeekStart  cantidad
# 0 2018-01-01    258006
# 1 2018-01-08    295629
# 2 2018-01-15    215605
# 3 2018-01-22    186968
# 4 2018-01-29    164441

# %%
df_week.tail()
# Out:
#     WeekStart  cantidad
# 47 2018-11-26     89477
# 48 2018-12-03     91585
# 49 2018-12-10    253195
# 50 2018-12-17    185679
# 51 2018-12-24    190663

# %% [markdown]
# Okay! The last one is day 24th. That is what we wanted!

# %%
df_week['Numero Semana']=df_week.index.values
df_week.head()
# Out:
#    WeekStart  cantidad  Numero Semana
# 0 2018-01-01    258006              0
# 1 2018-01-08    295629              1
# 2 2018-01-15    215605              2
# 3 2018-01-22    186968              3
# 4 2018-01-29    164441              4

# %%
df_week = df_week.rename(columns={'WeekStart': 'ds', 'cantidad': 'y'})
df_week.head()
# Out:
#           ds       y  Numero Semana
# 0 2018-01-01  258006              0
# 1 2018-01-08  295629              1
# 2 2018-01-15  215605              2
# 3 2018-01-22  186968              3
# 4 2018-01-29  164441              4

# %% [markdown]
# # Fit and predict

# %%
df_week['floor'] = 0.
df_week['cap'] = 5e5

m_week = Prophet(yearly_seasonality=True , growth='logistic', changepoint_range=0.95 , seasonality_mode="multiplicative"  )
m_week.fit(df_week)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
df_week.head()
# Out:
#           ds       y  Numero Semana  floor       cap
# 0 2018-01-01  258006              0    0.0  500000.0
# 1 2018-01-08  295629              1    0.0  500000.0
# 2 2018-01-15  215605              2    0.0  500000.0
# 3 2018-01-22  186968              3    0.0  500000.0
# 4 2018-01-29  164441              4    0.0  500000.0

# %%
df_week.tail()
# Out:
#            ds       y  Numero Semana  floor       cap
# 47 2018-11-26   89477             47    0.0  500000.0
# 48 2018-12-03   91585             48    0.0  500000.0
# 49 2018-12-10  253195             49    0.0  500000.0
# 50 2018-12-17  185679             50    0.0  500000.0
# 51 2018-12-24  190663             51    0.0  500000.0

# %%
future_week = m_week.make_future_dataframe(periods=60, freq='W-MON')

# to introduce floor value
future_week['floor'] = 0.
future_week['cap'] = 5e5


future_week.iloc[50:57]
# Out:
#            ds  floor       cap
# 50 2018-12-17    0.0  500000.0
# 51 2018-12-24    0.0  500000.0
# 52 2018-12-31    0.0  500000.0
# 53 2019-01-07    0.0  500000.0
# 54 2019-01-14    0.0  500000.0
# 55 2019-01-21    0.0  500000.0
# 56 2019-01-28    0.0  500000.0

# %%
forecast_week = m_week.predict(future_week)
#forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
forecast_week['Numerio Dia']=forecast_week.index.tolist()

forecast_week.tail()
# Out:
#             ds         trend       cap  floor    yhat_lower    yhat_upper  \
# 107 2020-01-20  30157.848880  500000.0    0.0   7614.109337  61994.977349
# 108 2020-01-27  29597.767793  500000.0    0.0   2857.240604  58200.735845
# 109 2020-02-03  29047.445268  500000.0    0.0  -1931.150451  56706.292377
# 110 2020-02-10  28506.735010  500000.0    0.0  -7940.032929  50429.946621
# 111 2020-02-17  27975.492035  500000.0    0.0 -10629.060628  45957.831879
#
#       trend_lower   trend_upper  multiplicative_terms  \
# 107  30157.808213  30157.889171              0.196795
# 108  29597.726449  29597.808677              0.068430
# 109  29047.403565  29047.486379             -0.086818
# 110  28506.692817  28506.776358             -0.238068
# 111  27975.449628  27975.533667             -0.354516
#
#      multiplicative_terms_lower  multiplicative_terms_upper    yearly  \
# 107                    0.196795                    0.196795  0.196795
# 108                    0.068430                    0.068430  0.068430
# 109                   -0.086818                   -0.086818 -0.086818
# 110                   -0.238068                   -0.238068 -0.238068
# 111                   -0.354516                   -0.354516 -0.354516
#
#      yearly_lower  yearly_upper  additive_terms  additive_terms_lower  \
# 107      0.196795      0.196795             0.0                   0.0
# 108      0.068430      0.068430             0.0                   0.0
# 109     -0.086818     -0.086818             0.0                   0.0
# 110     -0.238068     -0.238068             0.0                   0.0
# 111     -0.354516     -0.354516             0.0                   0.0
#
#      additive_terms_upper          yhat  Numerio Dia
# 107                   0.0  36092.773013          107
# 108                   0.0  31623.141020          108
# 109                   0.0  26525.592906          109
# 110                   0.0  21720.202711          110
# 111                   0.0  18057.740365          111

# %%
df_week.head()
# Out:
#           ds       y  Numero Semana  floor       cap
# 0 2018-01-01  258006              0    0.0  500000.0
# 1 2018-01-08  295629              1    0.0  500000.0
# 2 2018-01-15  215605              2    0.0  500000.0
# 3 2018-01-22  186968              3    0.0  500000.0
# 4 2018-01-29  164441              4    0.0  500000.0

# %% [markdown]
# ## Plots

# %%
fig2 = m_week.plot_components(forecast_week)
plt.show()

# %%
fig1 = m_week.plot(forecast_week)
plt.title(r'Weekly Model')
plt.show()

# %%
plt.scatter(x=forecast_week['Numerio Dia'].tolist(),y=forecast_week['yhat'].tolist(),color='r', label=r'Model')
plt.scatter(x=df_week.index.values.tolist(),y=df_week['y'].tolist(), label=r'Original data')
plt.legend()
plt.show()

# %% [markdown]
# # Comparison weekly and daily model

# %%
plt.figure()
fig2 = m_day.plot(forecast_day)
plt.title(r'Daily Model')
#plt.axhline(y=0., color='r', linestyle='-')

fig1 = m_week.plot(forecast_week)
plt.title(r'Weekly Model')
#plt.axhline(y=0., color='r', linestyle='-')
plt.show()

# %% [markdown]
# # ERROR ANALYSIS with the 2019 data

# %% [markdown]
# ### Loading functions

# %%
## Definición de funciones útiles
def error(y_true, y_pred): 
  
    """ Function that calculates the MAEN"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    s = (y_true - y_pred).mean()
    return s
  
def maen(y_true, y_pred): 
  
    """ Function that calculates the MAEN"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    s = np.abs(y_true - y_pred).sum()
    return s / (y_true.sum())
  
def maen_filtered(y_true, y_pred, fil_target, fil2_target=0, how='less'):
  
    """ Function that calculates the MAEN filtering results between fil & fil2 target"""
    t = pd.Series(y_true, name='so_target')
    p = pd.Series(y_pred, name='predicted')
    pred_df = pd.concat([t,p], axis = 1)
    pred_df["error_abs"] = abs(pred_df["predicted"]-pred_df["so_target"])
    if how=='less':
      pred_df_maxt = pred_df.loc[pred_df["so_target"] <= fil_target]
    if how=='more':
      pred_df_maxt = pred_df.loc[pred_df["so_target"] >= fil_target]
    else:
      boolean = (pred_df["so_target"] <= fil_target) & (pred_df["so_target"] >= fil2_target)
      pred_df_maxt = pred_df.loc[boolean]
      
    return pred_df_maxt["error_abs"].sum() / pred_df_maxt["so_target"].sum()

# %% [markdown]
# ## LOAD 2019 data

# %%
sql = """select * from dbo.marc_by_day_2019 order by Dia"""
df_day_2019 = pd.read_sql(sql, engine)
df_day_2019.head()
# Out:
#           Dia  cantidad
# 0  2019-01-01      4694
# 1  2019-01-02     59113
# 2  2019-01-03     61078
# 3  2019-01-04     61150
# 4  2019-01-05     53225

# %%
df_day_2019.tail()
# Out:
#            Dia  cantidad
# 19  2019-01-20     14899
# 20  2019-01-21     24258
# 21  2019-01-22     22017
# 22  2019-01-23     21896
# 23  2019-01-24       854

# %% [markdown]
# ### last one is not correct at all. So let's delete it

# %%
df_day_2019 = df_day_2019 [:-1]
df_day_2019.tail()
# Out:
#            Dia  cantidad
# 18  2019-01-19     41732
# 19  2019-01-20     14899
# 20  2019-01-21     24258
# 21  2019-01-22     22017
# 22  2019-01-23     21896

# %% [markdown]
# # Weeks

# %%
sql = """select * from dbo.marc_by_week_2019 order by WeekStart"""
df_week_2019 = pd.read_sql(sql, engine)
df_week_2019.head()
# Out:
#    WeekStart  cantidad
# 0 2018-12-31    190663
# 1 2019-01-07    281449
# 2 2019-01-14    264807
# 3 2019-01-21    199953
# 4 2019-01-28     83924

# %% [markdown]
# ### last one is not correct at all. So let's delete it

# %%
df_week_2019 = df_week_2019 [:-1]
df_week_2019.tail()
# Out:
#    WeekStart  cantidad
# 0 2018-12-31    190663
# 1 2019-01-07    281449
# 2 2019-01-14    264807
# 3 2019-01-21    199953

# %% [markdown]
# ## Transform data to fit the inputs of the functions

# %% [markdown]
# That means, make it arrays

# %% [markdown]
# ## Use 2019 data as true

# %% [markdown]
# ## Days

# %%
df_day_2019.head()
# Out:
#           Dia  cantidad
# 0  2019-01-01      4694
# 1  2019-01-02     59113
# 2  2019-01-03     61078
# 3  2019-01-04     61150
# 4  2019-01-05     53225

# %%
y_true_day=np.array(df_day_2019['cantidad'].tolist())
y_true_day
# Out:
# array([ 4694, 59113, 61078, 61150, 53225, 15093, 63359, 40469, 34142,
#        31066, 35928, 44750, 18239, 23058, 23326, 22687, 35273, 35638,
#        41732, 14899, 24258, 22017, 21896])

# %% [markdown]
# ## Use forecast data as predict

# %%
forecast_day.head()
# Out:
#           ds         trend       cap  floor    yhat_lower    yhat_upper  \
# 0 2018-01-01  18609.687672  100000.0    0.0  29827.900887  46586.034346
# 1 2018-01-02  18637.597003  100000.0    0.0  29701.508628  47212.141957
# 2 2018-01-03  18665.538591  100000.0    0.0  30723.430885  47752.405326
# 3 2018-01-04  18693.512445  100000.0    0.0  33050.672616  50630.414233
# 4 2018-01-05  18721.518572  100000.0    0.0  34738.155342  52539.136361
#
#     trend_lower   trend_upper  multiplicative_terms  \
# 0  18609.687672  18609.687672              1.050446
# 1  18637.597003  18637.597003              1.057224
# 2  18665.538591  18665.538591              1.111017
# 3  18693.512445  18693.512445              1.242939
# 4  18721.518572  18721.518572              1.319523
#
#    multiplicative_terms_lower     ...       weekly_lower  weekly_upper  \
# 0                    1.050446     ...          -0.093005     -0.093005
# 1                    1.057224     ...          -0.086588     -0.086588
# 2                    1.111017     ...          -0.029003     -0.029003
# 3                    1.242939     ...           0.110897      0.110897
# 4                    1.319523     ...           0.199622      0.199622
#
#      yearly  yearly_lower  yearly_upper  additive_terms  additive_terms_lower  \
# 0  1.143452      1.143452      1.143452             0.0                   0.0
# 1  1.143812      1.143812      1.143812             0.0                   0.0
# 2  1.140019      1.140019      1.140019             0.0                   0.0
# 3  1.132042      1.132042      1.132042             0.0                   0.0
# 4  1.119901      1.119901      1.119901             0.0                   0.0
#
#    additive_terms_upper          yhat  Numerio Dia
# 0                   0.0  38158.164860            0
# 1                   0.0  38341.709805            1
# 2                   0.0  39403.262101            2
# 3                   0.0  41928.406105            3
# 4                   0.0  43424.990593            4
#
# [5 rows x 22 columns]

# %% [markdown]
# ## TO datetime fromat

# %%
forecast_day['ds']=pd.to_datetime(forecast_day['ds'], format='%Y-%m-%d' )
forecast_day.head()
# Out:
#           ds         trend       cap  floor    yhat_lower    yhat_upper  \
# 0 2018-01-01  18609.687672  100000.0    0.0  29827.900887  46586.034346
# 1 2018-01-02  18637.597003  100000.0    0.0  29701.508628  47212.141957
# 2 2018-01-03  18665.538591  100000.0    0.0  30723.430885  47752.405326
# 3 2018-01-04  18693.512445  100000.0    0.0  33050.672616  50630.414233
# 4 2018-01-05  18721.518572  100000.0    0.0  34738.155342  52539.136361
#
#     trend_lower   trend_upper  multiplicative_terms  \
# 0  18609.687672  18609.687672              1.050446
# 1  18637.597003  18637.597003              1.057224
# 2  18665.538591  18665.538591              1.111017
# 3  18693.512445  18693.512445              1.242939
# 4  18721.518572  18721.518572              1.319523
#
#    multiplicative_terms_lower     ...       weekly_lower  weekly_upper  \
# 0                    1.050446     ...          -0.093005     -0.093005
# 1                    1.057224     ...          -0.086588     -0.086588
# 2                    1.111017     ...          -0.029003     -0.029003
# 3                    1.242939     ...           0.110897      0.110897
# 4                    1.319523     ...           0.199622      0.199622
#
#      yearly  yearly_lower  yearly_upper  additive_terms  additive_terms_lower  \
# 0  1.143452      1.143452      1.143452             0.0                   0.0
# 1  1.143812      1.143812      1.143812             0.0                   0.0
# 2  1.140019      1.140019      1.140019             0.0                   0.0
# 3  1.132042      1.132042      1.132042             0.0                   0.0
# 4  1.119901      1.119901      1.119901             0.0                   0.0
#
#    additive_terms_upper          yhat  Numerio Dia
# 0                   0.0  38158.164860            0
# 1                   0.0  38341.709805            1
# 2                   0.0  39403.262101            2
# 3                   0.0  41928.406105            3
# 4                   0.0  43424.990593            4
#
# [5 rows x 22 columns]

# %%
forecast_day.head()
# Out:
#           ds         trend       cap  floor    yhat_lower    yhat_upper  \
# 0 2018-01-01  18609.687672  100000.0    0.0  29827.900887  46586.034346
# 1 2018-01-02  18637.597003  100000.0    0.0  29701.508628  47212.141957
# 2 2018-01-03  18665.538591  100000.0    0.0  30723.430885  47752.405326
# 3 2018-01-04  18693.512445  100000.0    0.0  33050.672616  50630.414233
# 4 2018-01-05  18721.518572  100000.0    0.0  34738.155342  52539.136361
#
#     trend_lower   trend_upper  multiplicative_terms  \
# 0  18609.687672  18609.687672              1.050446
# 1  18637.597003  18637.597003              1.057224
# 2  18665.538591  18665.538591              1.111017
# 3  18693.512445  18693.512445              1.242939
# 4  18721.518572  18721.518572              1.319523
#
#    multiplicative_terms_lower     ...       weekly_lower  weekly_upper  \
# 0                    1.050446     ...          -0.093005     -0.093005
# 1                    1.057224     ...          -0.086588     -0.086588
# 2                    1.111017     ...          -0.029003     -0.029003
# 3                    1.242939     ...           0.110897      0.110897
# 4                    1.319523     ...           0.199622      0.199622
#
#      yearly  yearly_lower  yearly_upper  additive_terms  additive_terms_lower  \
# 0  1.143452      1.143452      1.143452             0.0                   0.0
# 1  1.143812      1.143812      1.143812             0.0                   0.0
# 2  1.140019      1.140019      1.140019             0.0                   0.0
# 3  1.132042      1.132042      1.132042             0.0                   0.0
# 4  1.119901      1.119901      1.119901             0.0                   0.0
#
#    additive_terms_upper          yhat  Numerio Dia
# 0                   0.0  38158.164860            0
# 1                   0.0  38341.709805            1
# 2                   0.0  39403.262101            2
# 3                   0.0  41928.406105            3
# 4                   0.0  43424.990593            4
#
# [5 rows x 22 columns]

# %% [markdown]
# ### filter data from 2018-12-31 to 2019-01-24 (NOT INCLUDED)

# %%
forecast_between2018_and_23_Jan_day= forecast_day[ ( forecast_day['ds'] < datetime(2019,1,24) ) & ( forecast_day['ds'] > datetime(2018,12,31) )]

# %%
y_predict_day=np.array(forecast_between2018_and_23_Jan_day['yhat'].tolist())
y_predict_day
# Out:
# array([ 31495.90958765,  32375.29067414,  34449.10831571,  35673.78348575,
#         36230.56637465,  26818.54773146,  30437.49244381,  30161.38072552,
#         30609.61912118,  32258.46926722,  33080.12215047,  33259.84043062,
#         23549.37673423,  26833.71035053,  26277.87398304,  26480.31565315,
#         27917.06410835,  28572.2934702 ,  28631.04109529,  18892.87274513,
#         22123.54667428,  21573.6536962 ,  21815.59782156])

# %% [markdown]
# ## WEEKS

# %%
y_true_week=np.array(df_week_2019['cantidad'].tolist())
y_true_week
# Out:
# array([190663, 281449, 264807, 199953])

# %%
forecast_week['ds']=pd.to_datetime(forecast_week['ds'], format='%Y-%m-%d' )

# %%
forecast_between2018_and_23_Jan_week= \
forecast_week[ ( forecast_week['ds'] < datetime(2019,1,22) ) & ( forecast_week['ds'] > datetime(2018,12,28) )]
forecast_between2018_and_23_Jan_week
# Out:
#            ds         trend       cap  floor     yhat_lower     yhat_upper  \
# 52 2018-12-31  80596.225763  500000.0    0.0  115738.879353  172629.821058
# 53 2019-01-07  79257.436172  500000.0    0.0   90210.681626  144476.125343
# 54 2019-01-14  77936.752742  500000.0    0.0   71629.953111  128673.037704
# 55 2019-01-21  76634.067816  500000.0    0.0   61731.479605  118892.302198
#
#      trend_lower   trend_upper  multiplicative_terms  \
# 52  80596.225659  80596.225851              0.787561
# 53  79257.435722  79257.436649              0.490640
# 54  77936.751812  77936.753730              0.300628
# 55  76634.066330  76634.069306              0.175522
#
#     multiplicative_terms_lower  multiplicative_terms_upper    yearly  \
# 52                    0.787561                    0.787561  0.787561
# 53                    0.490640                    0.490640  0.490640
# 54                    0.300628                    0.300628  0.300628
# 55                    0.175522                    0.175522  0.175522
#
#     yearly_lower  yearly_upper  additive_terms  additive_terms_lower  \
# 52      0.787561      0.787561             0.0                   0.0
# 53      0.490640      0.490640             0.0                   0.0
# 54      0.300628      0.300628             0.0                   0.0
# 55      0.175522      0.175522             0.0                   0.0
#
#     additive_terms_upper           yhat  Numerio Dia
# 52                   0.0  144070.644283           52
# 53                   0.0  118144.330962           53
# 54                   0.0  101366.759505           54
# 55                   0.0   90085.044415           55

# %%
y_predict_week=np.array(forecast_between2018_and_23_Jan_week['yhat'].tolist())
y_predict_week
# Out:
# array([ 144070.64428259,  118144.3309616 ,  101366.75950467,
#          90085.04441487])

# %% [markdown]
# # Now let's PLOT

# %%
def mae(y_true, y_pred): 
  
    """ Function that calculates the MAE"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    s = (np.abs(y_true - y_pred)).sum()
    return s / len(y_true)


def mse(y_true, y_pred):
    
    """ Function that calculates the MSE"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    s = ((y_true - y_pred)**2).sum()
    return s / (len(y_true))



def rmse(y_true, y_pred):
    
    """ Function that calculates the RMSE"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    s = ((y_true - y_pred)**2).sum()
    return (s / (len(y_true)))**0.5


def mape(y_true, y_pred):
    
    """ Function that calculates the MAPE"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    s = (  np.abs((y_true - y_pred)/y_true)  ).sum()
    return s/len(y_true)


def mase_with_seasonal_time_series(y_true, y_pred, m):
    
    """ Function that calculates the MASE
    
    If the result is larger than 1, a dummy classifier which predicts what they sold in the\
    same moment of the previous period, would score better. This result is extremely bad
    
    If we get a result close to 1 that means that we get the same score than a dummy \
    classifier. Which is bad as well
    
    The closer to 0, the better
    
    Inputs: m = "estacionalidad" or periodicity
            y_true, y_predict = real and predicted values of the series
    """
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    
    N=len(y_true)
    
    denominator_sum=0
    for j in range(m+1,N):
        denominator_sum += np.abs(y_true[j] - y_true[j-m])
        
    denominator = denominator_sum/(N-m)
    
    s = ( ( np.abs(y_true - y_pred ) ) / denominator_sum  ).sum()
    
    return s / len(y_true)

# %%
days_ds=forecast_between2018_and_23_Jan_day['ds']
days=np.arange(1,len(y_true_day)+1,1)
days

plt.figure(figsize=(15,10))
plt.plot(days,y_true_day, label=r'True Values' , linestyle='--', linewidth=2)
plt.plot(days,y_predict_day, label=r'Predicted Values', linestyle='--', linewidth=2)
plt.scatter(days,y_true_day)
plt.scatter(days,y_predict_day)

plt.xlabel('Days of January 2019')
plt.ylabel(r'Units sold that day')
plt.title('Error analysis')
plt.xticks(days)

plt.legend()

#increase all text
ax=plt.gca()
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels() + ax.legend().get_texts()):
    item.set_fontsize(18)

plt.show()

# %%
def print_errors(y_true_day, y_predict_day,m):
    print('The Mean Absolute Error (MAE) is               \
           {:.3E}\nThe Mean Absolute Error Normalized (MAEN) is   \
           {:.3}\nThe Root Mean Squred Error (RMSE) is           \
           {:.3E}\nThe Mean Absolute Percentage error (MAPE) is   \
           {:.3}\nThe Mean Absolute Scaled Error (MASE) is                  {:.3}'.format (mae(y_true_day,y_predict_day), \
                 maen(y_true_day,y_predict_day) , rmse(y_true_day,y_predict_day), mape(y_true_day,y_predict_day), \
                 mase_with_seasonal_time_series(y_true_day,y_predict_day,m)))

    
print_errors(y_true_day, y_predict_day,7)
# Out:
# The Mean Absolute Error (MAE) is                          1.072E+04
# The Mean Absolute Error Normalized (MAEN) is              0.313
# The Root Mean Squred Error (RMSE) is                      1.463E+04
# The Mean Absolute Percentage error (MAPE) is              0.487
# The Mean Absolute Scaled Error (MASE) is                  0.0613

# %% [markdown]
# # Changing flexibility (changepoint_prior_scale):
#
# https://facebook.github.io/prophet/docs/trend_changepoints.html#automatic-changepoint-detection-in-prophet
#
# By default is 0.05. The higher, the more overfit. Our problem now seems to underfit. So I have increased it. But it is worse :(

# %%
# to introduce floor value

df_day['floor'] = 0.
df_day['cap'] = 1e5

# Model parameters

m_day = Prophet(yearly_seasonality=True, weekly_seasonality=True ,  changepoint_range=0.95 , growth='logistic' \
                , seasonality_mode="multiplicative", changepoint_prior_scale=0.5)
m_day.fit(df_day)

# Create where to predict
future_day = m_day.make_future_dataframe(periods=365)

# to introduce floor value
future_day['floor'] = 0.
future_day['cap'] = 1e5

#Predict the data

forecast_day = m_day.predict(future_day)
#forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
forecast_day['Numerio Dia']=forecast_day.index.tolist()
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
fig2 = m_day.plot_components(forecast_day)
plt.show()

plt.figure(figsize=(15,10))
fig1 = m_day.plot(forecast_day)
plt.title(r'Daily Model')
plt.show()

# %% [markdown]
# ## Obtain y_true and y_predict

# %%
# Y_true:
y_true_day=np.array(df_day_2019['cantidad'].tolist())
print(y_true_day)

# Y_predict
forecast_day['ds']=pd.to_datetime(forecast_day['ds'], format='%Y-%m-%d' )
forecast_between2018_and_23_Jan_day= \
forecast_day[ ( forecast_day['ds'] < datetime(2019,1,24) ) & ( forecast_day['ds'] > datetime(2018,12,31) )]
y_predict_day=np.array(forecast_between2018_and_23_Jan_day['yhat'].tolist())
y_predict_day
# Out:
# [ 4694 59113 61078 61150 53225 15093 63359 40469 34142 31066 35928 44750
#  18239 23058 23326 22687 35273 35638 41732 14899 24258 22017 21896]
# array([ 26553.81117859,  26830.96992409,  28132.45703764,  28682.38603066,
#         28806.73661416,  20693.12604414,  23221.69138246,  22785.06927321,
#         22867.64142682,  23997.18150998,  24419.34071806,  24456.3805077 ,
#         16387.40118233,  18869.43502252,  18453.71644719,  18581.65378153,
#         19772.39313866,  20289.45369098,  20448.19279371,  12615.34455728,
#         15224.50467874,  14981.73427215,  15284.16660836])

# %%
days_ds=forecast_between2018_and_23_Jan_day['ds']
days=np.arange(1,len(y_true_day)+1,1)
days

plt.figure(figsize=(15,10))
plt.plot(days,y_true_day, label=r'True Values' , linestyle='--', linewidth=2)
plt.plot(days,y_predict_day, label=r'Predicted Values', linestyle='--', linewidth=2)
plt.scatter(days,y_true_day)
plt.scatter(days,y_predict_day)

plt.xlabel('Days of January 2019')
plt.ylabel(r'Units sold that day')
plt.title('Error analysis')
plt.xticks(days)

plt.legend()

#increase all text
ax=plt.gca()
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels() + ax.legend().get_texts()):
    item.set_fontsize(18)

plt.show()

# %%
print_errors(y_true_day, y_predict_day,7)
# Out:
# The Mean Absolute Error (MAE) is                          1.520E+04
# The Mean Absolute Error Normalized (MAEN) is              0.444
# The Root Mean Squred Error (RMSE) is                      1.877E+04
# The Mean Absolute Percentage error (MAPE) is              0.552
# The Mean Absolute Scaled Error (MASE) is                  0.0869

# %% [markdown]
# ### Ahora mismo no mejora, descartado por el momento

# %% [markdown]
# # Add Holidays / Sundays

# %%
import holidays

# %%
holidays.Spain()
# Out:
# {}

# %%
for date, name in sorted(holidays.Spain( years=2014).items()):
    print(date,name)
# Out:
# 2014-01-01 Año nuevo
# 2014-01-06 Epifanía del Señor
# 2014-04-18 Viernes Santo
# 2014-05-01 Día del Trabajador
# 2014-08-15 Asunción de la Virgen
# 2014-10-12 Día de la Hispanidad
# 2014-11-01 Todos los Santos
# 2014-12-06 Día de la constitución Española
# 2014-12-08 La Inmaculada Concepción
# 2014-12-25 Navidad

# %%
for date, name in sorted(holidays.Spain(prov='CAT', years=2014).items()):
    print(date,name)
# Out:
# 2014-01-01 Año nuevo
# 2014-01-06 Epifanía del Señor
# 2014-04-18 Viernes Santo
# 2014-04-21 Lunes de Pascua
# 2014-05-01 Día del Trabajador
# 2014-06-24 San Juan
# 2014-08-15 Asunción de la Virgen
# 2014-09-11 Día Nacional de Catalunya
# 2014-10-12 Día de la Hispanidad
# 2014-11-01 Todos los Santos
# 2014-12-06 Día de la constitución Española
# 2014-12-08 La Inmaculada Concepción
# 2014-12-25 Navidad
# 2014-12-26 San Esteban

# %%
datelist = pd.date_range(datetime(2010,1,1), datetime(2025,1,1)).tolist()
dia_de_la_madre_list=[]

for d in datelist:
    if d.weekday() == 6 and 1 <= d.day <= 7 and d.month == 5:
        dia_de_la_madre_list.append(d.strftime("%Y-%m-%d"))
        #print(d.strftime("%Y-%m-%d"))
print(dia_de_la_madre_list)
# Out:
# ['2010-05-02', '2011-05-01', '2012-05-06', '2013-05-05', '2014-05-04', '2015-05-03', '2016-05-01', '2017-05-07', '2018-05-06', '2019-05-05', '2020-05-03', '2021-05-02', '2022-05-01', '2023-05-07', '2024-05-05']

# %%
black_friday_list=[]

from datetime import timedelta

for d in datelist:
    if d.weekday() == 3 and 22 <= d.day <= 28 and d.month == 11:
        d = d + timedelta(days=1)
        black_friday_list.append(d.strftime("%Y-%m-%d"))
        #print(d.strftime("%Y-%m-%d"))
print(black_friday_list)
# Out:
# ['2010-11-26', '2011-11-25', '2012-11-23', '2013-11-29', '2014-11-28', '2015-11-27', '2016-11-25', '2017-11-24', '2018-11-23', '2019-11-29', '2020-11-27', '2021-11-26', '2022-11-25', '2023-11-24', '2024-11-29']

# %%
# When to start the calendar and when to finish
Starting_Year=2010
Last_Year=2025


""" Dia de la Madre """
# We predict the 1st Sunday of May which is El dia de la madre
# ONLY IN SPAIN!
#WE CONSIDER ALL THE PREVIOUS WEEK AS IMPORTANT (lower_window = -6)

dia_de_la_madre_list=[]

datelist = pd.date_range(datetime(Starting_Year,1,1), datetime(Last_Year,1,1)).tolist()
for d in datelist:
    if d.weekday() == 6 and 1 <= d.day <= 7 and d.month == 5:
        dia_de_la_madre_list.append(d.strftime("%Y-%m-%d"))
        #print(d.strftime("%Y-%m-%d"))


dia_de_la_madre = pd.DataFrame({
  'holiday': 'Dia de la madre',
  'ds': pd.to_datetime(dia_de_la_madre_list),
  'lower_window': -6,
  'upper_window': 0,
})

"""Spanish holidays (The ones that are in all spain, not the autonomic ones)"""

holidays_spain_list=[]

for year in range(Starting_Year,Last_Year):
    for date in holidays.Spain( years=year).items():
        holidays_spain_list.append(str(date[0]))


holidays_spain =  pd.DataFrame({
  'holiday': 'Regular Spanish Holidays',
  'ds': pd.to_datetime(holidays_spain_list),
  'lower_window': 0,
  'upper_window': 0,
})

""" Black Friday """
# We predict the 4th Thursday of November which is THanksGiving
# And then we add 1 day.
# IMPORTANT! Predicting the 4th Friday Would be Different!
# 4th friday is between the 22 and 28 inclusive
# Day after 4th Thursday is between the 23 and 29 inclusive

# We consider the Weekend and cyberMonday also as
# importan (upper_window = 3)

black_friday_list=[]


from datetime import timedelta

for d in datelist:
    if d.weekday() == 3 and 22 <= d.day <= 28 and d.month == 11:
        d = d + timedelta(days=1)
        black_friday_list.append(d.strftime("%Y-%m-%d"))

black_friday = pd.DataFrame({
  'holiday': 'Black Friday',
  'ds': pd.to_datetime(black_friday_list),
  'lower_window': 0,
  'upper_window': 3,
})



holidays_calendar = pd.concat(( holidays_spain, black_friday, dia_de_la_madre ))
holidays_calendar
# Out:
#                      holiday         ds  lower_window  upper_window
# 0   Regular Spanish Holidays 2010-01-01             0             0
# 1   Regular Spanish Holidays 2010-01-06             0             0
# 2   Regular Spanish Holidays 2010-04-02             0             0
# 3   Regular Spanish Holidays 2010-05-01             0             0
# 4   Regular Spanish Holidays 2010-08-15             0             0
# 5   Regular Spanish Holidays 2010-10-12             0             0
# 6   Regular Spanish Holidays 2010-11-01             0             0
# 7   Regular Spanish Holidays 2010-12-06             0             0
# 8   Regular Spanish Holidays 2010-12-08             0             0
# 9   Regular Spanish Holidays 2010-12-25             0             0
# 10  Regular Spanish Holidays 2011-01-01             0             0
# 11  Regular Spanish Holidays 2011-01-06             0             0
# 12  Regular Spanish Holidays 2011-04-22             0             0
# 13  Regular Spanish Holidays 2011-05-01             0             0
# 14  Regular Spanish Holidays 2011-08-15             0             0
# 15  Regular Spanish Holidays 2011-10-12             0             0
# 16  Regular Spanish Holidays 2011-11-01             0             0
# 17  Regular Spanish Holidays 2011-12-06             0             0
# 18  Regular Spanish Holidays 2011-12-08             0             0
# 19  Regular Spanish Holidays 2011-12-25             0             0
# 20  Regular Spanish Holidays 2012-01-01             0             0
# 21  Regular Spanish Holidays 2012-01-06             0             0
# 22  Regular Spanish Holidays 2012-04-06             0             0
# 23  Regular Spanish Holidays 2012-05-01             0             0
# 24  Regular Spanish Holidays 2012-08-15             0             0
# 25  Regular Spanish Holidays 2012-10-12             0             0
# 26  Regular Spanish Holidays 2012-11-01             0             0
# 27  Regular Spanish Holidays 2012-12-06             0             0
# 28  Regular Spanish Holidays 2012-12-08             0             0
# 29  Regular Spanish Holidays 2012-12-25             0             0
# ..                       ...        ...           ...           ...
# 0               Black Friday 2010-11-26             0             3
# 1               Black Friday 2011-11-25             0             3
# 2               Black Friday 2012-11-23             0             3
# 3               Black Friday 2013-11-29             0             3
# 4               Black Friday 2014-11-28             0             3
# 5               Black Friday 2015-11-27             0             3
# 6               Black Friday 2016-11-25             0             3
# 7               Black Friday 2017-11-24             0             3
# 8               Black Friday 2018-11-23             0             3
# 9               Black Friday 2019-11-29             0             3
# 10              Black Friday 2020-11-27             0             3
# 11              Black Friday 2021-11-26             0             3
# 12              Black Friday 2022-11-25             0             3
# 13              Black Friday 2023-11-24             0             3
# 14              Black Friday 2024-11-29             0             3
# 0            Dia de la madre 2010-05-02            -6             0
# 1            Dia de la madre 2011-05-01            -6             0
# 2            Dia de la madre 2012-05-06            -6             0
# 3            Dia de la madre 2013-05-05            -6             0
# 4            Dia de la madre 2014-05-04            -6             0
# 5            Dia de la madre 2015-05-03            -6             0
# 6            Dia de la madre 2016-05-01            -6             0
# 7            Dia de la madre 2017-05-07            -6             0
# 8            Dia de la madre 2018-05-06            -6             0
# 9            Dia de la madre 2019-05-05            -6             0
# 10           Dia de la madre 2020-05-03            -6             0
# 11           Dia de la madre 2021-05-02            -6             0
# 12           Dia de la madre 2022-05-01            -6             0
# 13           Dia de la madre 2023-05-07            -6             0
# 14           Dia de la madre 2024-05-05            -6             0
#
# [180 rows x 4 columns]

# %%
# to introduce floor value

df_day['floor'] = 0.
df_day['cap'] = 1e5

# Model parameters

m_day = Prophet(yearly_seasonality=True, weekly_seasonality=True ,  changepoint_range=0.95 , growth='logistic' \
                , seasonality_mode="multiplicative", holidays = holidays_calendar)
m_day.fit(df_day)

# Create where to predict
future_day = m_day.make_future_dataframe(periods=365)

# to introduce floor value
future_day['floor'] = 0.
future_day['cap'] = 1e5

#Predict the data

forecast_day = m_day.predict(future_day)
#forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
forecast_day['Numerio Dia']=forecast_day.index.tolist()
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
fig2 = m_day.plot_components(forecast_day)
plt.show()

plt.figure(figsize=(15,10))
fig1 = m_day.plot(forecast_day)
plt.title(r'Daily Model')
plt.show()

# %% [markdown]
# ## Obtain y_true and y_predict

# %%
# Y_true:
y_true_day=np.array(df_day_2019['cantidad'].tolist())
print(y_true_day)

# Y_predict
forecast_day['ds']=pd.to_datetime(forecast_day['ds'], format='%Y-%m-%d' )
forecast_between2018_and_23_Jan_day= \
forecast_day[ ( forecast_day['ds'] < datetime(2019,1,24) ) & ( forecast_day['ds'] > datetime(2018,12,31) )]
y_predict_day=np.array(forecast_between2018_and_23_Jan_day['yhat'].tolist())
y_predict_day
# Out:
# [ 4694 59113 61078 61150 53225 15093 63359 40469 34142 31066 35928 44750
#  18239 23058 23326 22687 35273 35638 41732 14899 24258 22017 21896]
# array([ 12007.1656648 ,  25549.40860526,  26373.63120152,  26065.18526838,
#         26064.12832429,   4725.41272271,  20564.17537595,  19727.25044428,
#         19601.00098545,  20474.85388926,  20279.60767319,  20427.33027639,
#         12924.6533424 ,  15412.90890215,  14826.9498258 ,  14958.59716222,
#         16087.0634532 ,  16170.91574875,  16594.51729248,   9487.92205554,
#         12205.35540787,  11887.30062113,  12261.47999084])

# %%
days_ds=forecast_between2018_and_23_Jan_day['ds']
days=np.arange(1,len(y_true_day)+1,1)
days

plt.figure(figsize=(15,10))
plt.plot(days,y_true_day, label=r'True Values' , linestyle='--', linewidth=2)
plt.plot(days,y_predict_day, label=r'Predicted Values', linestyle='--', linewidth=2)
plt.scatter(days,y_true_day)
plt.scatter(days,y_predict_day)

plt.xlabel('Days of January 2019')
plt.ylabel(r'Units sold that day')
plt.title('Error analysis')
plt.xticks(days)

plt.legend()

#increase all text
ax=plt.gca()
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels() + ax.legend().get_texts()):
    item.set_fontsize(18)

plt.show()

# %%
print_errors(y_true_day, y_predict_day,7)
# Out:
# The Mean Absolute Error (MAE) is                          1.770E+04
# The Mean Absolute Error Normalized (MAEN) is              0.517
# The Root Mean Squred Error (RMSE) is                      2.069E+04
# The Mean Absolute Percentage error (MAPE) is              0.53
# The Mean Absolute Scaled Error (MASE) is                  0.101

# %% [markdown]
# # Calmaps

# %%
df_day['ds']=pd.to_datetime(df_day['ds'], format='%Y-%m-%d' )

df_calmap = df_day.set_index('ds')
df_calmap_serie=(df_calmap['y'])
df_calmap_serie
# Out:
# ds
# 2018-01-01     4959
# 2018-01-02    55614
# 2018-01-03    60449
# 2018-01-04    62760
# 2018-01-05    55927
# 2018-01-06    18297
# 2018-01-07    62209
# 2018-01-08    46206
# 2018-01-09    34389
# 2018-01-10    31499
# 2018-01-11    28835
# 2018-01-12    43302
# 2018-01-13    49189
# 2018-01-14    17656
# 2018-01-15    26465
# 2018-01-16    24509
# 2018-01-17    25985
# 2018-01-18    37510
# 2018-01-19    38281
# 2018-01-20    45199
# 2018-01-21    15056
# 2018-01-22    26324
# 2018-01-23    24928
# 2018-01-24    24907
# 2018-01-25    26587
# 2018-01-26    30390
# 2018-01-27    38776
# 2018-01-28    12798
# 2018-01-29    21627
# 2018-01-30    21907
#               ...
# 2018-12-02     7562
# 2018-12-03     9493
# 2018-12-04    11453
# 2018-12-05    13330
# 2018-12-06    10535
# 2018-12-07    20956
# 2018-12-08    18256
# 2018-12-09    14970
# 2018-12-10    47872
# 2018-12-11    37439
# 2018-12-12    36658
# 2018-12-13    30595
# 2018-12-14    35895
# 2018-12-15    49766
# 2018-12-16    33129
# 2018-12-17    20469
# 2018-12-18    21649
# 2018-12-19    23438
# 2018-12-20    26090
# 2018-12-21    27339
# 2018-12-22    33565
# 2018-12-23    27569
# 2018-12-24    25616
# 2018-12-25     2010
# 2018-12-26    32618
# 2018-12-27    36924
# 2018-12-28    33180
# 2018-12-29    32746
# 2018-12-30    24070
# 2018-12-31    18096
# Name: y, Length: 365, dtype: int64

# %%
import calmap

fig = plt.figure(figsize=(20,8))
ax = fig.add_subplot(111)
cax = calmap.yearplot(df_calmap_serie, ax=ax  )#, cmap='YlGn')
cb=fig.colorbar(cax.get_children()[1], ax=cax, orientation='horizontal')

plt.title('2018 Sales')


#increase all text
ax=plt.gca()
for item in ([ ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()  ):
    item.set_fontsize(16)

cb.ax.tick_params(labelsize=14) 

ax.title.set_fontsize(22)

plt.savefig('CalendarMap_lowquality.png', format='png', dpi=70, bbox='tight')

plt.show()

# %%
cb.get_ticks()
